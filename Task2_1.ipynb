# %%
import cv2
from matplotlib import pyplot as plt

# %%
image = cv2.imread('images2/andrew-small-EfhCUc_fjrU-unsplash.jpg')

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
height, width, _ = image_rgb.shape
print('Высота изображения в пикселях', height)
print('Ширина изображения в пикселях', width)
# Out:
# Высота изображения в пикселях 3507
# Ширина изображения в пикселях 5261

# %%
image_rgb[1761][2644]
# Out:
# array([156, 185, 191], dtype=uint8)
