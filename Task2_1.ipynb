# %%
import cv2
from matplotlib import pyplot as plt

# %%
image = cv2.imread('images2/fabian-medrano-6cVF-qE0NF4-unsplash.jpg')

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
height, width, _ = image_rgb.shape
print('Высота изображения в пикселях', height)
print('Ширина изображения в пикселях', width)
# Out:
# Высота изображения в пикселях 3864
# Ширина изображения в пикселях 5152

# %%
image_rgb[1921][2585]
# Out:
# array([26, 24, 12], dtype=uint8)
