# %%
import cv2
from matplotlib import pyplot as plt

# %%
image = cv2.imread('images2/kiki-siepel-BEwxLSN_bKU-unsplash.jpg')

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
image_rgb = image_rgb[1252:1991, 1522:2471]
plt.imshow(image_rgb)
plt.axis('off')
plt.show()
