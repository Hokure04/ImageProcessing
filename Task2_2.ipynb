# %%
import cv2
from matplotlib import pyplot as plt

# %%
image = cv2.imread('images2/fabian-medrano-6cVF-qE0NF4-unsplash.jpg')

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
image_rgb = image_rgb[1452:2411, 2346:2965]
plt.imshow(image_rgb)
plt.axis('off')
plt.show()
